# %%
import pandas as pd
from sqlalchemy import create_engine
from mysql.connector import Error

# %%
Db1 = "/Users/hessari/Desktop/Project2New/Resources/WHO_Dataset/WHO_Life_Expectancy_Data.csv"
Db2 = "/Users/hessari/Desktop/Project2New/Resources/World_Bank_Dataset/Metadata_Country_API_SP.DYN.LE00.IN_DS2_en_csv_v2_10576744.csv"
Db3 = "/Users/hessari/Desktop/Project2New/Resources/Ourworldindata/happiness-cantril-ladder.csv"
Db4 = "/Users/hessari/Desktop/Project2New/Resources/Ourworldindata/life-satisfaction-vs-life-expectancy.csv"
Db5 = "/Users/hessari/Desktop/Project2New/Resources/Ourworldindata/share-of-people-who-say-they-are-happy.csv"

# %%
# !pip install mysql-connector

# %%
Db1_df = pd.read_csv(Db1)
Db1_df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#      ...      Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
Db1_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
Db1_df_rename = Db1_df.rename(index=str, columns={"Life expectancy ": "Life_expectancy", "Adult Mortality": "Adult_mortality"})
Db1_df_rename.head()
Db1_df_rename.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
Life_expectancy_df = Db1_df[['Country','Year','Status','Life expectancy ','Adult Mortality','infant deaths']]
Life_expectancy_df = Life_expectancy_df.rename(index=str, columns={"Life expectancy ": "Life_expectancy",
                                                                   "infant deaths": "Infant_deaths",
                                                                  "Adult Mortality": "Adult_Mortality"})
Life_expectancy_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_Mortality',
#        'Infant_deaths'],
#       dtype='object')

# %%
Health_df = Db1_df[['Country','Year','Hepatitis B','Measles ', 'Polio', ' HIV/AIDS', ' BMI ','Diphtheria ']].copy()
Health_df = Health_df.rename(index=str, columns={"Hepatitis B": "Hepatitis_B",
                                                "Measles ": "Measles",
                                                " HIV/AIDS": "HIV/AIDS",
                                                " BMI ": "BMI",
                                                "Diphtheria ": "Diphtheria"})
Health_df.head()
# Out:
#        Country  Year  Hepatitis_B  Measles  Polio  HIV/AIDS   BMI  Diphtheria
# 0  Afghanistan  2015         65.0     1154    6.0       0.1  19.1        65.0
# 1  Afghanistan  2014         62.0      492   58.0       0.1  18.6        62.0
# 2  Afghanistan  2013         64.0      430   62.0       0.1  18.1        64.0
# 3  Afghanistan  2012         67.0     2787   67.0       0.1  17.6        67.0
# 4  Afghanistan  2011         68.0     3013   68.0       0.1  17.2        68.0

# %%
Db2_df = pd.read_csv(Db2)
Db2_df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  Central Bureau of Statistics and Central Bank ...        Aruba         NaN
# 1  Central Statistics Organization; World Bank st...  Afghanistan         NaN
# 2  IMF ; Source of population estimates: UN Popul...       Angola         NaN
# 3  Albanian Institute of Statistics ; Source of p...      Albania         NaN
# 4  Government of Andorra, Department of Statistic...      Andorra         NaN

# %%
Db2_df.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName',
#        'Unnamed: 5'],
#       dtype='object')

# %%
Income_status_df = Db2_df[['TableName', 'Region', 'IncomeGroup']].copy()
Income_status_df = Income_status_df.rename(index=str, columns={"TableName": "Country"})
Income_status_df.head()
# Out:
#        Country                     Region          IncomeGroup
# 0        Aruba  Latin America & Caribbean          High income
# 1  Afghanistan                 South Asia           Low income
# 2       Angola         Sub-Saharan Africa  Lower middle income
# 3      Albania      Europe & Central Asia  Upper middle income
# 4      Andorra      Europe & Central Asia          High income

# %%
Db3_df = pd.read_csv(Db3)
Db3_df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2008
# 1  Afghanistan  AFG  2009
# 2  Afghanistan  AFG  2010
# 3  Afghanistan  AFG  2011
# 4  Afghanistan  AFG  2012
#
#    World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))
# 0                                           3.723590
# 1                                           4.401778
# 2                                           4.758381
# 3                                           3.831719
# 4                                           3.782938

# %%
Db4_df = pd.read_csv(Db4)
Db4_df.head()
# Out:
#         Entity Code  Year  Life expectancy (years)  \
# 0  Afghanistan  AFG  1800                      NaN
# 1  Afghanistan  AFG  1820                      NaN
# 2  Afghanistan  AFG  1870                      NaN
# 3  Afghanistan  AFG  1913                      NaN
# 4  Afghanistan  AFG  1950                   27.537
#
#    Life satisfaction (measured from lowest=0 to highest=10 on Cantril Ladder)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total population (Gapminder)
# 0                     3280000.0
# 1                     3280000.0
# 2                     4207000.0
# 3                     5730000.0
# 4                     8151455.0

# %%
Db5_df = pd.read_csv(Db5)
Db5_df.head()
# Out:
#     Entity Code  Year        (%)
# 0  Albania  ALB  1998  33.433434
# 1  Albania  ALB  2004  58.799999
# 2  Algeria  DZA  2004  80.733231
# 3  Algeria  DZA  2014  79.894180
# 4  Andorra  AND  2009  92.878632

# %%
Happiness_df = [Db3_df, Db4_df, Db5_df]
Happiness_df = pd.concat(Happiness_df)
# Happiness_df.groupby(["Entity"]).mean()
Happiness_df = Happiness_df[Happiness_df["Year"] > 2008]
# Happiness_df = Happiness_df[Happiness_df["Life satisfaction (measured from lowest=0 to highest=10 on Cantril Ladder)"] > 0]
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
Happiness_df.columns
# Out:
# Index([' (%)', 'Code', 'Entity', 'Life expectancy (years)',
#        'Life satisfaction (measured from lowest=0 to highest=10 on Cantril Ladder)',
#        'Total population (Gapminder)',
#        'World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))',
#        'Year'],
#       dtype='object')

# %%
Happiness_df
# Out:
#            (%) Code               Entity  Life expectancy (years)  \
# 1          NaN  AFG          Afghanistan                      NaN
# 2          NaN  AFG          Afghanistan                      NaN
# 3          NaN  AFG          Afghanistan                      NaN
# 4          NaN  AFG          Afghanistan                      NaN
# 5          NaN  AFG          Afghanistan                      NaN
# 6          NaN  AFG          Afghanistan                      NaN
# 7          NaN  AFG          Afghanistan                      NaN
# 8          NaN  AFG          Afghanistan                      NaN
# 9          NaN  AFG          Afghanistan                      NaN
# 10         NaN  AFG          Afghanistan                      NaN
# 12         NaN  ALB              Albania                      NaN
# 13         NaN  ALB              Albania                      NaN
# 14         NaN  ALB              Albania                      NaN
# ...

# %%
Happiness_df = Happiness_df[['Entity', 'Life expectancy (years)', 'Life satisfaction (measured from lowest=0 to highest=10 on Cantril Ladder)',
                            'World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))', 'Total population (Gapminder)', 'Year']].copy()

# %%
Happiness_df = Happiness_df.rename(index=str, columns={"World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))": "World_Happiness_Report_0=worst10=best",
                                                      "Entity": "Country"})

# %%
Happiness_df = Happiness_df.rename(index=str, columns={"Life satisfaction (measured from lowest=0 to highest=10 on Cantril Ladder)": "Life_satisfactin_0=worst10=best",
                                                      "Life expectancy (years)": "Life_expectancy_(years)", "Total population (Gapminder)": "Tot_population_(Gapminder)"})

# %%
Happiness_df.head()
# Out:
#         Country  Life_expectancy_(years)  Life_satisfactin_0=worst10=best  \
# 62  Afghanistan                   60.243                         3.723590
# 63  Afghanistan                   60.754                         4.401778
# 64  Afghanistan                   61.226                         4.758381
# 65  Afghanistan                   61.666                         3.831719
# 66  Afghanistan                   62.086                         3.782938
#
#     World_Happiness_Report_0=worst10=best  Tot_population_(Gapminder)  Year
# 62                                    NaN                  29839994.0  2008
# 63                                    NaN                  30577756.0  2009
# 64                                    NaN                  31411743.0  2010
# 65                                    NaN                  32358260.0  2011
# 66                                    NaN                  33397058.0  2012

# %%
Happiness_df = Happiness_df.reset_index(drop=True)
Happiness_df.head()
# Out:
#        Country  Life_expectancy_(years)  Life_satisfactin_0=worst10=best  \
# 0  Afghanistan                   60.243                         3.723590
# 1  Afghanistan                   60.754                         4.401778
# 2  Afghanistan                   61.226                         4.758381
# 3  Afghanistan                   61.666                         3.831719
# 4  Afghanistan                   62.086                         3.782938
#
#    World_Happiness_Report_0=worst10=best  Tot_population_(Gapminder)  Year
# 0                                    NaN                  29839994.0  2008
# 1                                    NaN                  30577756.0  2009
# 2                                    NaN                  31411743.0  2010
# 3                                    NaN                  32358260.0  2011
# 4                                    NaN                  33397058.0  2012

# %%
rds_connecting_string= "user:password@localhost:3306/Project2"
engine= create_engine('mysql+pymysql://{}'.format(rds_connecting_string))

# %%
Life_expectancy_df.to_sql(name='Life_expectancy', con=engine, if_exists='append', index=True)

# %%
Health_df.to_sql(name='Health_conditions', con=engine, if_exists='append', index=True)

# %%
Income_status_df.to_sql(name='Income', con=engine, if_exists='append', index=True)

# %%
Happiness_df.to_sql(name='Happiness', con=engine, if_exists='append', index=True)
